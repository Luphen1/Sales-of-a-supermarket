# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#inspecting and loading of dataframe

df = pd.read_excel(r"C:\Users\LUPHEN\Documents\Supermarket_Stores.xlsx")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# 1  10:29:00         Cash   76.40                 4.761905        3.8200
# 2  13:23:00  Credit card  324.31                 4.761905       16.2155
# 3  20:33:00      Ewallet  465.76                 4.761905       23.2880
# 4  10:37:00      Ewallet  604.17                 4.761905       30.2085
#
#    Rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
#identifying and handling for null values
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#Checking for duplicate values
duplicate=df.drop_duplicates(inplace=True)
duplicate

# %%
#Finding more about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(8)
# memory usage: 132.9+ KB

# %%
#standardizing datatypes

#Convert Date column to datatime datatypes
df['Date']= pd.to_datetime(df['Date'])
df['Date'] 

#Convert Time column to time datatypes
df['Time'] = df['Time'].astype(str)
df['Time']

df['Time'] = pd.to_timedelta(df['Time'])
df['Time']
# Out:
# 0     0 days 13:08:00
# 1     0 days 10:29:00
# 2     0 days 13:23:00
# 3     0 days 20:33:00
# 4     0 days 10:37:00
#             ...
# 995   0 days 13:46:00
# 996   0 days 17:16:00
# 997   0 days 13:22:00
# 998   0 days 15:33:00
# 999   0 days 13:28:00
# Name: Time, Length: 1000, dtype: timedelta64[ns]

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# 0 0 days 13:08:00      Ewallet  522.83                 4.761905       26.1415
# 1 0 days 10:29:00         Cash   76.40                 4.761905        3.8200
# 2 0 days 13:23:00  Credit card  324.31                 4.761905       16.2155
# 3 0 days 20:33:00      Ewallet  465.76                 4.761905       23.2880
# 4 0 days 10:37:00      Ewallet  604.17                 4.761905       30.2085
#
#    Rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date                       Time        cogs  \
# count                        1000                       1000  1000.00000
# mean   2019-02-14 00:05:45.600000     0 days 15:24:41.880000   307.58738
# min           2019-01-01 00:00:00            0 days 10:00:00    10.17000
# 25%           2019-01-24 00:00:00            0 days 12:43:00   118.49750
# 50%           2019-02-13 00:00:00            0 days 15:19:00   241.76000
# 75%           2019-03-08 00:00:00            0 days 18:15:00   448.90500
# max           2019-03-30 00:00:00            0 days 20:59:00   993.00000
# std                           NaN  0 days 03:11:31.667297780   234.17651
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000
# std               6.131498e-14     11.708825     1.71858

# %% [markdown]
# ##  Visualize column Quantity with boxplot to check for outliers

# %%
#Visualize column Quantity for outliers

plt.figure(figsize=(10,6))
sns.boxplot(data=df, y='Quantity')
plt.ylabel('Quantity')
plt.title('Outliers')
plt.show()

# %% [markdown]
# ### (1).What was the distribution of sales across different branches?

# %%
#Grouping by branch and summing the Total sales
sales_distribution =df.groupby('Branch')['Total'].sum().round(2).sort_values().reset_index()

#Sorting the result by Total sales in descending order
sales_distribution_sorted=sales_distribution.sort_values('Total', ascending=False)
sales_distribution_sorted
# Out:
#   Branch      Total
# 2      C  110568.71
# 1      A  106200.37
# 0      B  106197.67

# %%
#Visualize the output code above

plt.figure(figsize=(10, 6))
sns.barplot(data=sales_distribution_sorted, x='Total', y='Branch')
plt.xlabel('Total')
plt.ylabel('Branch')
plt.title('Sales by branch')
plt.show()

# %% [markdown]
# ### (2).How does sales revenue vary across different customer types?

# %%
customer_sales_revenue =df.groupby('Customer type')['Total'].sum().round(2).reset_index()
customer_sales_revenue
# Out:
#   Customer type      Total
# 0        Member  164223.44
# 1        Normal  158743.30

# %%
#Visualize the output code above

plt.figure(figsize=(10,6))
sns.barplot(data=customer_sales_revenue, x='Customer type',y='Total')
plt.xlabel('customer type')
plt.ylabel('Total')
plt.title('Revenue by customer type')
plt.show()

# %% [markdown]
# ### (3).What was the average gross income for each product line?

# %%
gross_income=df.groupby('Product line')['gross income'].mean().round(2).reset_index()
gross_income_sorted=gross_income.sort_values('gross income',ascending=False)
gross_income_sorted
# Out:
#              Product line  gross income
# 4      Home and lifestyle         16.03
# 5       Sports and travel         15.81
# 3       Health and beauty         15.41
# 2      Food and beverages         15.37
# 0  Electronic accessories         15.22
# 1     Fashion accessories         14.53

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=gross_income_sorted,x='gross income',y='Product line')
plt.title('Average gross income by product line')
plt.show()

# %% [markdown]
# ### (4).What month had the best revenue income?

# %%
# Extract month from 'Date' column
df['Month'] = pd.to_datetime(df['Date']).dt.strftime('%b')
df['Month']


month_order = ['Jan','Feb','Mar']
month_order

#Reorder column month
df['Month'] = pd.Categorical(df['Month'],categories = month_order,ordered = True)
monthly_sales = df.sort_values('Month')
monthly_sales


monthly_sales = df.groupby('Month')['Total'].sum().round(2).reset_index().sort_values('Total', ascending = True)
monthly_sales
# Out:
#   Month      Total
# 1   Feb   97219.37
# 2   Mar  109455.51
# 0   Jan  116291.87

# %%
plt.figure(figsize=(10,6))
sns.lineplot(monthly_sales, x='Month', y='Total',marker = 'o',color = 'Green')
plt.title('Revenue income by month')
plt.grid()
plt.show()
plt.tight_layout()

# %% [markdown]
# ### (5).Find payment type with the most revenue.

# %%
Payment_revenue=df.groupby('Payment')['Total'].sum().round(2).reset_index()
Payment_revenue_sorted=Payment_revenue.sort_values('Total',ascending=False)
Payment_revenue_sorted
# Out:
#        Payment      Total
# 0         Cash  112206.57
# 2      Ewallet  109993.11
# 1  Credit card  100767.07

# %%
plt.figure(figsize=(10,6))
sns.barplot(Payment_revenue_sorted,x='Total',y='Payment')
plt.title('Payment type by revenue')
plt.show()
plt.tight_layout()

# %% [markdown]
# ### (6).Find the correlation relationship between cogs,gross income,Rating,Unit price,Quantity and Tax 5%.

# %%
corr_Relationship = df[['cogs','gross income','Rating','Unit price','Quantity','Tax 5%']].corr()
corr_Relationship
# Out:
#                   cogs  gross income    Rating  Unit price  Quantity    Tax 5%
# cogs          1.000000      1.000000 -0.036442    0.633962  0.705510  1.000000
# gross income  1.000000      1.000000 -0.036442    0.633962  0.705510  1.000000
# Rating       -0.036442     -0.036442  1.000000   -0.008778 -0.015815 -0.036442
# Unit price    0.633962      0.633962 -0.008778    1.000000  0.010778  0.633962
# Quantity      0.705510      0.705510 -0.015815    0.010778  1.000000  0.705510
# Tax 5%        1.000000      1.000000 -0.036442    0.633962  0.705510  1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr_Relationship, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Relationship')
plt.show()

# %%
#Renaming columns 

df.rename(columns={'cogs': 'Cogs', 'gross margin percentage': 'Gross Margin Percentage', 'gross income': 'Gross Income'}, inplace=True)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date            Time      Payment    Cogs  Gross Margin Percentage  \
# 0   2019-01-05 0 days 13:08:00      Ewallet  522.83                 4.761905
# 1   2019-03-08 0 days 10:29:00         Cash   76.40                 4.761905
# 2   2019-03-03 0 days 13:23:00  Credit card  324.31                 4.761905
# 3   2019-01-27 0 days 20:33:00      Ewallet  465.76                 4.761905
# 4   2019-02-08 0 days 10:37:00      Ewallet  604.17                 4.761905
# ..         ...             ...          ...     ...                      ...
# 995 2019-01-29 0 days 13:46:00      Ewallet   40.35                 4.761905
# 996 2019-03-02 0 days 17:16:00      Ewallet  973.80                 4.761905
# 997 2019-02-09 0 days 13:22:00         Cash   31.84                 4.761905
# 998 2019-02-22 0 days 15:33:00         Cash   65.82                 4.761905
# 999 2019-02-18 0 days 13:28:00         Cash  618.38                 4.761905
#
#      Gross Income  Rating Month
# 0         26.1415     9.1   Jan
# 1          3.8200     9.6   Mar
# 2         16.2155     7.4   Mar
# 3         23.2880     8.4   Jan
# 4         30.2085     5.3   Feb
# ..            ...     ...   ...
# 995        2.0175     6.2   Jan
# 996       48.6900     4.4   Mar
# 997        1.5920     7.7   Feb
# 998        3.2910     4.1   Feb
# 999       30.9190     6.6   Feb
#
# [1000 rows x 18 columns]

# %% [markdown]
# ### (7).What was the percentage gender demographic across the dataframe?

# %%
total_gender=df['Gender'].size
gender_demographic=(df.groupby('Gender').size()/ total_gender*100).round(2)
gender_demographic
# Out:
# Gender
# Female    50.1
# Male      49.9
# dtype: float64

# %%
plt.figure(figsize=(10,6))
gender_demographic.plot(kind='pie',autopct='%.2f',startangle= 30)
plt.title('Gender Demographic')
plt.show()

# %% [markdown]
# ### (8).What was the average rating for each product lines?

# %%
plt.figure(figsize=(10,6))
product_line_rating = df['Rating'].groupby(df['Product line']).mean().round(2).reset_index()
product_line_rating_sorted=product_line_rating.sort_values('Rating',ascending=False)
product_line_rating_sorted
# Out:
#              Product line  Rating
# 2      Food and beverages    7.11
# 1     Fashion accessories    7.03
# 3       Health and beauty    7.00
# 0  Electronic accessories    6.92
# 5       Sports and travel    6.92
# 4      Home and lifestyle    6.84

# %%
plt.figure(figsize=(10,6))
sns.barplot(product_line_rating_sorted,x='Rating',y='Product line')
plt.title('Average rating by product line')
plt.show()
plt.tight_layout()

# %% [markdown]
# ### (9).What city had the best order quantity?

# %%
city_order_quantity=df.groupby('City')['Quantity'].size()
city_order_quantity
# Out:
# City
# Mandalay     332
# Naypyitaw    328
# Yangon       340
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(10,6))
city_order_quantity.plot(kind='pie',autopct='%.2f',startangle= 60)
plt.title('City Sales')
# Out:
# Text(0.5, 1.0, 'City Sales')

# %% [markdown]
# ### (10).Which product lines had the highest and lowest percentage sales volumes?

# %%
total_sales = df['Total'].sum()
product_line_sales_percentage = (df.groupby('Product line')['Total'].sum() / total_sales * 100).round(2)
sorted_product_line=product_line_sales_percentage.sort_values(ascending=False)
sorted_product_line
# Out:
# Product line
# Food and beverages        17.38
# Sports and travel         17.07
# Electronic accessories    16.82
# Fashion accessories       16.81
# Home and lifestyle        16.68
# Health and beauty         15.23
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(10,6))
sorted_product_line.plot(kind='pie',autopct='%.2f',startangle= 60)
plt.title('Percentage sales by product line')
plt.show()
plt.tight_layout()

# %%
#Created column weekdays
df['Weekdays'] = pd.to_datetime(df['Date']).dt.strftime('%a')
df['Weekdays']
# Out:
# 0      Sat
# 1      Fri
# 2      Sun
# 3      Sun
# 4      Fri
#       ...
# 995    Tue
# 996    Sat
# 997    Sat
# 998    Fri
# 999    Mon
# Name: Weekdays, Length: 1000, dtype: object

# %%
#Re_ordered column weekdays
Weekdays = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
Weekdays

df['Weekdays'] = pd.Categorical(df['Weekdays'],categories = Weekdays,ordered = True)
weekday_sales = df.sort_values('Weekdays')
weekday_sales.head()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 999  849-09-3807      A     Yangon        Member  Female
# 179  342-65-4817      C  Naypyitaw        Member    Male
# 872  544-55-9589      B   Mandalay        Member  Female
# 543  243-47-2663      C  Naypyitaw        Member    Male
# 184  586-25-0848      A     Yangon        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 999     Fashion accessories       88.34         7  30.919  649.299 2019-02-18
# 179       Health and beauty       86.80         3  13.020  273.420 2019-01-28
# 872  Electronic accessories       21.43        10  10.715  225.015 2019-01-28
# 543  Electronic accessories       18.77         6   5.631  118.251 2019-01-28
# 184       Sports and travel       12.34         7   4.319   90.699 2019-03-04
#
#                Time      Payment    Cogs  Gross Margin Percentage  \
# 999 0 days 13:28:00         Cash  618.38                 4.761905
# 179 0 days 16:47:00      Ewallet  260.40                 4.761905
# 872 0 days 11:51:00         Cash  214.30                 4.761905
# 543 0 days 16:43:00  Credit card  112.62                 4.761905
# 184 0 days 11:19:00  Credit card   86.38                 4.761905
#
#      Gross Income  Rating Month Weekdays
# 999        30.919     6.6   Feb      Mon
# 179        13.020     9.9   Jan      Mon
# 872        10.715     6.2   Jan      Mon
# 543         5.631     5.5   Jan      Mon
# 184         4.319     6.7   Mar      Mon

# %% [markdown]
# ### (11).How does weekly sales vary across the dataframe?

# %%
week_sales = df.groupby('Weekdays')[['Quantity','Total']].sum().round(2).reset_index().sort_values(['Quantity','Total'], ascending = True)
week_sales
# Out:
#   Weekdays  Quantity     Total
# 0      Mon       638  37899.08
# 3      Thu       755  45349.25
# 4      Fri       758  43926.34
# 6      Sun       778  44457.89
# 2      Wed       800  43731.14
# 1      Tue       862  51482.25
# 5      Sat       919  56120.81

# %%
plt.figure(figsize=(10,6))
sns.lineplot(week_sales, x ='Weekdays' ,y ='Total',marker = 'o',color = 'purple')
plt.title('Total Sale Trend Over Days')
plt.grid()
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(week_sales, x ='Weekdays' ,y ='Quantity',marker = 'o',color = 'green')
plt.title('Quantity Trend Over Days')
plt.grid()
plt.show()
plt.tight_layout()
